# %%
# %load_ext autoreload
# %autoreload 2
from lethal_heat.heat_func import Vecellio22
import xarray as xr
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
v22 = Vecellio22(kind = 'slinear')

# %%
import numpy as np
a = np.array([[40, 44],[46, 47]])
b = np.array([[30, 40],[50, 60]])
v22.islethal(a, b)
# Out:
# array([[False,  True],
#        [ True,  True]])

# %%
v22.islethal(0,0)
# Out:
# False

# %%
v22 = Vecellio22()
v22.plot(a, b)

# %%
a1 = xr.DataArray(a,).chunk([1,1])
a2 = xr.DataArray(b,).chunk([1,1])

# %%
test = v22.islethal(a1, a2)

# %%
test.compute()
# Out:
# <xarray.DataArray (dim_0: 2, dim_1: 2)>
# array([[False,  True],
#        [ True,  True]])
# Dimensions without coordinates: dim_0, dim_1
